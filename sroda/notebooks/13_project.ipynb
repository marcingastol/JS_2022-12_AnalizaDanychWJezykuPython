# %%
# %pip install pandas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Project

# %%
data = pd.read_csv("2.csv")

# %%
data
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      02/01/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      04/01/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      05/01/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      08/01/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      09/01/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
data.shape

# %%
data.tail(20)

# %%
data.dtypes

# %%
data["Depth"].describe()
# Out:
# count    23412.000000
# mean        70.767911
# std        122.651898
# min         -1.100000
# 25%         14.522500
# 50%         33.000000
# 75%         54.000000
# max        700.000000
# Name: Depth, dtype: float64

# %%
data.corr()["Depth"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_41460\2604768002.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()["Depth"]
# Latitude                     -0.081020
# Longitude                    -0.085861
# Depth                         1.000000
# Depth Error                  -0.074609
# Depth Seismic Stations        0.174663
# Magnitude                     0.023457
# Magnitude Error              -0.076918
# Magnitude Seismic Stations   -0.015254
# Azimuthal Gap                -0.171162
# Horizontal Distance          -0.073832
# Horizontal Error             -0.016467
# Root Mean Square             -0.134002
# Name: Depth, dtype: float64

# %%
data1 = data.corr()
a, b = plot.subplots(1,1)
sns.heatmap(data1, vmax=0.9)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_41460\1205563237.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data1 = data.corr()
# <AxesSubplot: >

# %%
sns.distplot(np.log(data["Magnitude"]))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_41460\1084189931.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(data["Magnitude"]))
# <AxesSubplot: xlabel='Magnitude', ylabel='Density'>

# %%
sns.set()
plot.hist(data["Depth"], bins=50)
# Out:
# (array([5.468e+03, 3.496e+03, 6.941e+03, 1.709e+03, 1.017e+03, 5.400e+02,
#         4.390e+02, 4.590e+02, 4.470e+02, 2.740e+02, 2.650e+02, 2.050e+02,
#         1.740e+02, 1.250e+02, 1.480e+02, 1.180e+02, 9.400e+01, 5.200e+01,
#         3.900e+01, 4.300e+01, 2.900e+01, 1.100e+01, 1.900e+01, 1.500e+01,
#         1.800e+01, 3.800e+01, 3.300e+01, 3.900e+01, 2.800e+01, 3.600e+01,
#         3.400e+01, 2.700e+01, 2.700e+01, 2.600e+01, 3.000e+01, 3.800e+01,
#         3.700e+01, 5.400e+01, 8.900e+01, 9.300e+01, 1.140e+02, 1.120e+02,
#         1.320e+02, 1.030e+02, 7.800e+01, 4.600e+01, 2.800e+01, 1.200e+01,
#         8.000e+00, 5.000e+00]),
#  array([ -1.1  ,  12.922,  26.944,  40.966,  54.988,  69.01 ,  83.032,
#          97.054, 111.076, 125.098, 139.12 , 153.142, 167.164, 181.186,
#         195.208, 209.23 , 223.252, 237.274, 251.296, 265.318, 279.34 ,
#         293.362, 307.384, 321.406, 335.428, 349.45 , 363.472, 377.494,
# ...
